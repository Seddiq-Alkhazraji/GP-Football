# %%
# !git clone https://github.com/prashantghimire/sofifa-web-scraper.git
# Out:
# Cloning into 'sofifa-web-scraper'...

# %%
# %cd sofifa-web-scraper
# Out:
# C:\Users\ASUS\Downloads\sofifa-web-scraper

# %%
# !pip3 install -r requirements.txt
# !playwright install chromium
# Out:
# ...
#   Using cached greenlet-3.1.1-cp312-cp312-win_amd64.whl.metadata (3.9 kB)
# ...
# Using cached greenlet-3.1.1-cp312-cp312-win_amd64.whl (299 kB)
# ...
#   Attempting uninstall: greenlet
#     Found existing installation: greenlet 3.3.0
#     Uninstalling greenlet-3.3.0:
#       Successfully uninstalled greenlet-3.3.0
# ...
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\ASUS\anaconda3\Lib\site-packages\~.eenlet'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gevent 25.9.1 requires greenlet>=3.2.2; platform_python_implementation == "CPython", but you have greenlet 3.1.1 which is incompatible.

# %%
# %pip install -r requirements.txt

# !playwright install chromium
# Out:
# ...
#
# ...

# %%
import sys

# !{sys.executable} -m pip install -r requirements.txt

# !{sys.executable} -m pip install playwright

# !playwright install chromium

# %%
import sys

# %env PYTHONIOENCODING=utf-8

# %cd C:\Users\ASUS\Downloads\sofifa-web-scraper
# Out:
# env: PYTHONIOENCODING=utf-8
# C:\Users\ASUS\Downloads\sofifa-web-scraper

# %%
import sys

# %env PYTHONIOENCODING=utf-8

# %cd C:\Users\ASUS\Downloads\sofifa-web-scraper

# !{sys.executable} src/scrape_player_urls.py
# Out:
# env: PYTHONIOENCODING=utf-8
# C:\Users\ASUS\Downloads\sofifa-web-scraper
# ...
# SoFIFA Player URL Scraper
# ...
#
# This will scrape ALL player URLs from sofifa.com
# The process may take several minutes...
#
# Features:
#   - Headless mode (no browser window)
#   - Resource blocking for faster loading
#   - Cloudflare retry with 10s backoff (3 retries)
#   - Saves after each page
# ...
#
# [Page 1] Scraping: https://sofifa.com/players?type=all&lg%5B0%5D=13&lg%5B1%5D=31&lg%5B2%5D=53&lg%5B3%5D=19&lg%5B4%5D=16&r=250044&set=true
#   âœ“ Extracted 60 player URLs
#   Next button exists: True
#   ðŸ’¾ Saved 60 unique URLs to player_urls.csv
#
# [Page 2] Scraping: https://sofifa.com/players?type=all&lg%5B0%5D=13&lg%5B1%5D=31&lg%5B2%5D=53&lg%5B3%5D=19&lg%5B4%5D=16&r=250044&set=true&offset=60
#   âœ“ Extracted 60 player URLs
#   Next button exists: True
#   ðŸ’¾ Saved 120 unique URLs to player_urls.csv
#
# ...

# %%
# !{sys.executable} src/sofifa_scraper.py

# %%
import pandas as pd

# Load the data from the CSV file the scraper created
df = pd.read_csv('player_stats.csv')

# Display the first 5 rows
df.head()

# %%
df.columns
# Out:
# Index(['player_id', 'version', 'name', 'full_name', 'description', 'image',
#        'height_cm', 'weight_kg', 'dob', 'positions', 'overall_rating',
#        'potential', 'value', 'wage', 'preferred_foot', 'weak_foot',
#        'skill_moves', 'international_reputation', 'body_type', 'real_face',
#        'release_clause', 'specialities', 'club_id', 'club_name',
#        'club_league_id', 'club_league_name', 'club_logo', 'club_rating',
#        'club_position', 'club_kit_number', 'club_joined',
#        'club_contract_valid_until', 'country_id', 'country_name',
#        'country_league_id', 'country_league_name', 'country_flag',
#        'country_rating', 'country_position', 'country_kit_number',
#        'attacking_crossing', 'attacking_finishing',
#        'attacking_heading_accuracy', 'attacking_short_passing',
#        'attacking_volleys', 'skill_dribbling', 'skill_curve',
#        'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
# ...

# %%
df.shape
# Out:
# (5686, 77)

# %%
df['roles'].unique()
# Out:
# array(['Advanced forward ++, Attack, Support, Versatile',
#        'Advanced forward ++, Attack, Support, Versatile, False 9 +, Build-up, Attack',
#        'Inside forward ++, Balanced, Attack, Inside forward ++, Attack, Balanced, Roaming',
#        ...,
#        'Ball-playing defender +, Defend, Build-up, Aggressive, Holding +, Defend, Ball-winning, Roaming',
#        'Shadow striker +, Attack, Inside forward +, Balanced, Attack, Advanced forward +, Attack, Support, Versatile',
#        'Fullback +, Defend, Balanced, Versatile, Holding +, Defend, Ball-winning, Roaming'],
#       dtype=object)

# %%
df.loc[3, 'roles']
# Out:
# 'Deep-Lying playmaker ++, Build-up, Defend, Roaming, Playmaker ++, Attack, Roaming'
